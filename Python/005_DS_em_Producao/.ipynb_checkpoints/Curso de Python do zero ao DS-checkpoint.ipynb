# %% [markdown]
# # 0. Pacotes

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # 1. Carregando a base de dados

# %%
data = pd.read_csv('datasets/kc_house_data.csv')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## 1.1. Número de linhas e colunas

# %%
data.shape
# Out:
# (21613, 21)

# %% [markdown]
# - Temos 21.613 linhas e 21 colunas.

# %% [markdown]
# ## 1.2. Nome das colunas

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## 1.3. Ordenando as linhas pela variável `price`

# %%
data.sort_values('price') # ordem crescente
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1149           670     43377     1.0           0     0  ...      3
# ...

# %%
data.sort_values('price', ascending=False) # ordem decrescente
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %% [markdown]
# # 2. Respondendo às perguntas

# %% [markdown]
# ## 1. Quantas casas estão disponíveis para compra?
#
# 21.613 casas.

# %% [markdown]
# ## 2. Quantos atributos as casas possuem?
#
# Há 21 atributos.

# %% [markdown]
# ## 3. Quais são os atributos das casas?
#
# - 'id',
# - 'date',
# - 'price',
# - 'bedrooms',
# - 'bathrooms',
# - 'sqft_living',
# - 'sqft_lot',
# - 'floors',
# - 'waterfront',
# - 'view',
# - 'condition',
# - 'grade',
# - 'sqft_above',
# - 'sqft_basement',
# - 'yr_built',
# - 'yr_renovated',
# - 'zipcode',
# - 'lat',
# - 'long',
# - 'sqft_living15',
# - 'sqft_lot15'

# %% [markdown]
# ## 4. Qual a casa mais cara?
#
# A casa mais cara é a do id 7252, que custa `$7.700.000`

# %% [markdown]
# ## 5. Qual a casa com maior número de quartos?

# %%
data.sort_values('bedrooms', ascending=False) # ordem decrescente
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# ...           ...              ...        ...       ...        ...
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 875    6306400140  20140612T000000  1095000.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %% [markdown]
# A casa com id 2402100895, com 33 quartos.

# %% [markdown]
# ## 6. Qual a soma total de quartos do conjunto de dados?

# %%
data['bedrooms'].sum()
# Out:
# 72854

# %% [markdown]
# Há 72.854 quartos no conjunto de dados como um todo.

# %% [markdown]
# ## 7. Quantas casas possuem 2 banheiros?

# %%
data_2_wc = data[data['bathrooms'] == 2]

# %%
data_2_wc.shape
# Out:
# (1930, 21)

# %% [markdown]
# 1930 casa possuem 2 banheiros.

# %% [markdown]
# ## 8. Qual o preço médio de todas as casas no conjunto de dados?

# %%
data['price'].mean().round(2)
# Out:
# 540088.14

# %% [markdown]
# As casas custam, em média, $ 540.088,14.

# %% [markdown]
# ## 9. Qual o preço médio de casas com 2 banheiros?

# %%
data_2_wc['price'].mean().round(2)
# Out:
# 457889.72

# %% [markdown]
# As casas com dois banheiros custam, em média, $ 457.889,72.

# %% [markdown]
# ## 10. Qual o preço mínimo entre as casas com 3 quartos?

# %%
data_3_bedrooms = data[data['bedrooms'] == 3]

# %%
data_3_bedrooms.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
# 6  1321400060  20140627T000000  257500.0         3       2.25         1715
# 7  2008000270  20150115T000000  291850.0         3       1.50         1060
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 4      8080     1.0           0     0  ...      8        1680              0
# 6      6819     2.0           0     0  ...      7        1715              0
# 7      9711     1.0           0     0  ...      7        1060              0
#
# ...

# %%
data_3_bedrooms['price'].min()
# Out:
# 82000.0

# %% [markdown]
# O preço mínimo de uma casa com 3 quartos é $ 82.000,00.

# %% [markdown]
# # 3. Novas perguntas do CEO

# %% [markdown]
# ## 1. Qual a data do imóvel mais antigo no portfólio?

# %% [markdown]
# ## 2. Quantos imóveis possuem o número máximo de andares?

# %% [markdown]
# ## 3. Criar uma classificação para os imóveis, separando-os em baixo e alto padrão de acordo com o preço.
#
# - Acima de $ 540.000 -> alto padrão
# - Abaixo de $ 540.000 -> baixo padrão

# %% [markdown]
# ## 4. Gostaria de um relatório ordenado pelo preço e contendo as seguintes informações:
#
# - id do imóvel
# - data que o imóvel ficou disponível para compra
# - número de quartos
# - o tamanho total do terreno
# - o preço
# - a classificação do imóvel (alto e baixo padrão)

# %% [markdown]
# ## 5. Mapa indicando onde as casas estão localizadas geograficamente

# %% [markdown]
# # 4. Planejamento de solução:

# %% [markdown]
# ## 4.1 Produto Final

# %% [markdown]
# - Email + 2 anexos
#     + Email:
#         - Texto: Perguntas e Respostas
#     + Anexo:
#         - Um relatório .csv
#         - A foto de um mapa em html.

# %% [markdown]
# ## 4.2 Ferramenta
# - Python

# %% [markdown]
# ## 4.3 Processo
#
# - **Como fazer? (Resposndendo as perguntas)**
#
#     - Ordenar o conjunto de dados pela menor data
#     - Encontrar os números de andares e determinar o maior
#     - Contar quantos imóveis tenho com esta quantidade de andares
#     - Criar uma nova coluna chamada de standard
#         + Para cada linha eu vou comparar a coluna "price"
#         + Se "price" > 540.000 -> high_standard
#         + Se "price" < 540.000 -> low_standard
#
#     - Selecionar as colunas desejadas (ou excluir as não desejadas)
#     - Buscar uma biblioteca para criar mapas
#     - Aprender a usar a função de criar mapas

# %% [markdown]
# # 5. Tipos de variáveis em Python

# %% [markdown]
# - Numérica: integer, float
# - Categóricas: character, string
# - Dates: date, timestamp
#     + date: Ano-Mes-Dia
#     + timestamp: Ano-Mes-Dia H:M:S

# %% [markdown]
# - Identifique os tipos de variáveis, pois as operações vão depender disso. `dtypes`

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# - Tipos de variáveis:

# %%
data.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# - Temos que converter de object para date, a variável date.

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ## 5.1. Convertendo de diferentes formatos

# %% [markdown]
# ### Inteiro -> Float

# %%
data['bedrooms'] = data['bedrooms'].astype(float)

# %% [markdown]
# ### Float -> Inteiro

# %%
data['bedrooms'] = data['bedrooms'].astype(int)

# %% [markdown]
# # 6. Manipulação de dados

# %% [markdown]
# - Criar
# - Deletar
# - Selecionar:
#     + Forma 01: Pelo nome das colunas
#     + Forma 02: Pelos índices das colunas
#     + Forma 03: Pelos índices das linhas e pelos nomes das colunas
#     + Forma 04: Usando operador booleano

# %%
data1 = data.copy()

# %%
data1.head
# Out:
# <bound method NDFrame.head of                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
# ...

# %%
data1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## 6.1. Criação de variáveis

# %%
# Criando uma nova variável
data1['meu_nome'] = "neidinha"

# Checando 
data1[['id', 'date', 'meu_nome']]
# Out:
#                id       date  meu_nome
# 0      7129300520 2014-10-13  neidinha
# 1      6414100192 2014-12-09  neidinha
# 2      5631500400 2015-02-25  neidinha
# 3      2487200875 2014-12-09  neidinha
# 4      1954400510 2015-02-18  neidinha
# ...           ...        ...       ...
# 21608   263000018 2014-05-21  neidinha
# 21609  6600060120 2015-02-23  neidinha
# 21610  1523300141 2014-06-23  neidinha
# 21611   291310100 2015-01-16  neidinha
# 21612  1523300157 2014-10-15  neidinha
#
# [21613 rows x 3 columns]

# %%
# Criando data
data1['data_nasc'] = pd.to_datetime('1990-05-22')

# %%
# Checando 
data1[['id', 'date', 'meu_nome', 'data_nasc']]
# Out:
#                id       date  meu_nome  data_nasc
# 0      7129300520 2014-10-13  neidinha 1990-05-22
# 1      6414100192 2014-12-09  neidinha 1990-05-22
# 2      5631500400 2015-02-25  neidinha 1990-05-22
# 3      2487200875 2014-12-09  neidinha 1990-05-22
# 4      1954400510 2015-02-18  neidinha 1990-05-22
# ...           ...        ...       ...        ...
# 21608   263000018 2014-05-21  neidinha 1990-05-22
# 21609  6600060120 2015-02-23  neidinha 1990-05-22
# 21610  1523300141 2014-06-23  neidinha 1990-05-22
# 21611   291310100 2015-01-16  neidinha 1990-05-22
# 21612  1523300157 2014-10-15  neidinha 1990-05-22
#
# [21613 rows x 4 columns]

# %%
data1.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# meu_nome                 object
# data_nasc        datetime64[ns]
# dtype: object

# %% [markdown]
# ## 6.2. Deletando variáveis

# %%
data2 = data1.drop(['meu_nome'], axis = 1)

# %%
data1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'meu_nome', 'data_nasc'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'data_nasc'],
#       dtype='object')

# %%
- Deletando uma lista de variáveis:

# %%
data2 = data1.drop(['meu_nome', 'data_nasc'], axis = 1)

# %%
data2.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## 6.3. Selecionando variáveis

# %% [markdown]
# ### 6.3.1. Direto pelo nome das colunas

# %%
data['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
data[['id', 'date']]
# Out:
#                id       date
# 0      7129300520 2014-10-13
# 1      6414100192 2014-12-09
# 2      5631500400 2015-02-25
# 3      2487200875 2014-12-09
# 4      1954400510 2015-02-18
# ...           ...        ...
# 21608   263000018 2014-05-21
# 21609  6600060120 2015-02-23
# 21610  1523300141 2014-06-23
# 21611   291310100 2015-01-16
# 21612  1523300157 2014-10-15
#
# [21613 rows x 2 columns]

# %% [markdown]
# ### 6.3.2. Direto pelos índices das linhas e colunas

# %%
data.iloc[0:10, 0:3]
# Out:
#            id       date      price
# 0  7129300520 2014-10-13   221900.0
# 1  6414100192 2014-12-09   538000.0
# 2  5631500400 2015-02-25   180000.0
# 3  2487200875 2014-12-09   604000.0
# 4  1954400510 2015-02-18   510000.0
# 5  7237550310 2014-05-12  1225000.0
# 6  1321400060 2014-06-27   257500.0
# 7  2008000270 2015-01-15   291850.0
# 8  2414600126 2015-04-15   229500.0
# 9  3793500160 2015-03-12   323000.0

# %%
data.iloc[:, :] # tudo
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data.iloc[0:5, :]
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# ### 6.3.3. Índices das linhas e nomes das colunas

# %%
data.loc[0:10, ['id', 'price']]
# Out:
#             id      price
# 0   7129300520   221900.0
# 1   6414100192   538000.0
# 2   5631500400   180000.0
# 3   2487200875   604000.0
# 4   1954400510   510000.0
# 5   7237550310  1225000.0
# 6   1321400060   257500.0
# 7   2008000270   291850.0
# 8   2414600126   229500.0
# 9   3793500160   323000.0
# 10  1736800520   662500.0

# %% [markdown]
# ### 6.3.4. Índices booleanos

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols = [True, True, True, True, True, True, True, False, True, True, False, True, False, True, False, True, False, True, False, True, False]

# %%
len(cols)
# Out:
# 21

# %%
data.loc[0:10, cols]
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520 2014-10-13   221900.0         3       1.00         1180
# 1   6414100192 2014-12-09   538000.0         3       2.25         2570
# 2   5631500400 2015-02-25   180000.0         2       1.00          770
# 3   2487200875 2014-12-09   604000.0         4       3.00         1960
# 4   1954400510 2015-02-18   510000.0         3       2.00         1680
# 5   7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6   1321400060 2014-06-27   257500.0         3       2.25         1715
# 7   2008000270 2015-01-15   291850.0         3       1.50         1060
# 8   2414600126 2015-04-15   229500.0         3       1.00         1780
# 9   3793500160 2015-03-12   323000.0         3       2.50         1890
# 10  1736800520 2015-04-03   662500.0         3       2.50         3560
#
#     sqft_lot  waterfront  view  grade  sqft_basement  yr_renovated      lat  \
# ...

# %% [markdown]
# # 7. Respondendo às perguntas de negócio

# %%
# 1. Data mais antiga
data.sort_values('date', ascending = True)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02   437500.0         3       2.25         1970
# 9596    472000620 2014-05-02   790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02   675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02   555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02   440000.0         4       2.25         2160
# ...           ...        ...        ...       ...        ...          ...
# 7898   1422700040 2015-05-14   183000.0         3       1.00         1170
# 928    8730000270 2015-05-14   359000.0         2       2.75         1370
# 5637   7923600250 2015-05-15   450000.0         5       2.00         1870
# 13053  5101400871 2015-05-24   445500.0         2       1.75         1390
# 16594  9106000005 2015-05-27  1310000.0         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# 2. Quantos imóveis com andares máximo?
data['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %% [markdown]
# - O máximo é 3.5.

# %%
data[data['floors'] == 3.5]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 875    6306400140 2014-06-12  1095000.0         0       0.00         3064
# 10077  1972202010 2014-08-01   435000.0         3       3.00         1440
# 11594  3180100023 2015-01-30   544000.0         3       2.50         1760
# 14885  8673400177 2015-04-02   525000.0         3       3.00         1730
# 15424  1702900664 2015-04-16   479000.0         2       2.50         1730
# 18477  1346300150 2014-10-20  3300000.0         8       4.00         7710
# 20308  1972200426 2014-09-18   525000.0         2       2.75         1310
# 20772  1972200428 2014-06-25   563500.0         3       2.50         1400
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 875        4764     3.5           0     2  ...      7        3064
# 10077      1350     3.5           0     2  ...      8        1440
# 11594      1755     3.5           0     0  ...      8        1760
# ...

# %%
data[data['floors'] == 3.5][['id', 'floors']]
# Out:
#                id  floors
# 875    6306400140     3.5
# 10077  1972202010     3.5
# 11594  3180100023     3.5
# 14885  8673400177     3.5
# 15424  1702900664     3.5
# 18477  1346300150     3.5
# 20308  1972200426     3.5
# 20772  1972200428     3.5

# %%
data[data['floors'] == 3.5][['id', 'floors']].shape
# Out:
# (8, 2)

# %%
- 8 imóveis tem andares 3.5.

# %%
# 3. Criar classificação
data['level'] = 'standard'

# %%
data['price'] > 540000
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: price, Length: 21613, dtype: bool

# %%
data.loc[data['price'] > 540000, 'level']
# Out:
# 3        standard
# 5        standard
# 10       standard
# 15       standard
# 21       standard
#            ...
# 21598    standard
# 21599    standard
# 21600    standard
# 21605    standard
# 21606    standard
# Name: level, Length: 7919, dtype: object

# %%
data.loc[data['price'] > 540000, 'level'] = 'high_level'

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
data.loc[data['price'] < 540000, 'level'] = 'low_level'

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# 4. Relatório ordenado pelo preço
data[['id', 'date', 'price', 'bedrooms', 'sqft_lot', 'level']]
# Out:
#                id       date     price  bedrooms  sqft_lot       level
# 0      7129300520 2014-10-13  221900.0         3      5650   low_level
# 1      6414100192 2014-12-09  538000.0         3      7242   low_level
# 2      5631500400 2015-02-25  180000.0         2     10000   low_level
# 3      2487200875 2014-12-09  604000.0         4      5000  high_level
# 4      1954400510 2015-02-18  510000.0         3      8080   low_level
# ...           ...        ...       ...       ...       ...         ...
# 21608   263000018 2014-05-21  360000.0         3      1131   low_level
# 21609  6600060120 2015-02-23  400000.0         4      5813   low_level
# 21610  1523300141 2014-06-23  402101.0         2      1350   low_level
# 21611   291310100 2015-01-16  400000.0         3      2388   low_level
# 21612  1523300157 2014-10-15  325000.0         2      1076   low_level
#
# [21613 rows x 6 columns]

# %%
data[['id', 'date', 'price', 'bedrooms', 'sqft_lot', 'level']].sort_values('price', ascending = False)
# Out:
#                id       date      price  bedrooms  sqft_lot       level
# 7252   6762700020 2014-10-13  7700000.0         6     27600  high_level
# 3914   9808700762 2014-06-11  7062500.0         5     37325  high_level
# 9254   9208900037 2014-09-19  6885000.0         6     31374  high_level
# 4411   2470100110 2014-08-04  5570000.0         5     35069  high_level
# 1448   8907500070 2015-04-13  5350000.0         5     23985  high_level
# ...           ...        ...        ...       ...       ...         ...
# 8274   3883800011 2014-11-05    82000.0         3     10426   low_level
# 16198  3028200080 2015-03-24    81000.0         2      9975   low_level
# 465    8658300340 2014-05-23    80000.0         1      5050   low_level
# 15293    40000362 2014-05-06    78000.0         2     16344   low_level
# 1149   3421079032 2015-02-17    75000.0         1     43377   low_level
#
# [21613 rows x 6 columns]

# %%
report = data[['id', 'date', 'price', 'bedrooms', 'sqft_lot', 'level']].sort_values('price', ascending = False)

# %%
report.to_csv('datasets/report_aula02.csv', index = False)

# %%
# 5. Mapear as casas geograficamente

# %% [markdown]
# - Vamos usar o Plotly
# - A função a ser utilizada é: Scatter MapBox

# %%
data_mapa = data[['id', 'lat', 'long', 'price']]

# %%
mapa = px.scatter_mapbox(data_mapa, lat = 'lat', lon = 'long', 
                         hover_name = 'id',
                         hover_data = ['price'],
                         color_discrete_sequence = ['fuchsia'],
                         zoom = 5,
                         height = 300)

# %%
mapa.update_layout(mapbox_style = 'open-street-map')
mapa.update_layout(height = 600, margin={'r':0, 't':0, 'l':0, 'b':0})
mapa.show
# Out:
# <bound method BaseFigure.show of Figure({
#     'data': [{'customdata': array([[221900.],
#                                    [538000.],
#                                    [180000.],
#                                    ...,
#                                    [402101.],
#                                    [400000.],
#                                    [325000.]]),
#               'hovertemplate': ('<b>%{hovertext}</b><br><br>lat' ... '{customdata[0]}<extra></extra>'),
#               'hovertext': array([7.12930052e+09, 6.41410019e+09, 5.63150040e+09, ..., 1.52330014e+09,
#                                   2.91310100e+08, 1.52330016e+09]),
#               'lat': array([47.5112, 47.721 , 47.7379, ..., 47.5944, 47.5345, 47.5941]),
#               'legendgroup': '',
#               'lon': array([-122.257, -122.319, -122.233, ..., -122.299, -122.069, -122.299]),
#               'marker': {'color': 'fuchsia'},
#               'mode': 'markers',
#               'name': '',
# ...

# %% [markdown]
# - Salvando o mapa em html.

# %%
mapa.write_html('datasets/map_house_rocket.html')

# %% [markdown]
# - Mais informações sobre os mapas com plotly: https://plotly.com/python/scattermapbox/

# %% [markdown]
# # 8. Mais perguntas (Exercícios)

# %% [markdown]
# 1. Crie uma nova coluna chamada: "house_age"
#     + Se o valor da coluna "date" for maior do que 2014-01-01 => 'new_house'
#     + Caso contrário => 'old_house'

# %% [markdown]
# 2. Crie uma nova coluna chamada: "dormitory_type"
#     + Se o valor da coluna "bedrooms" for igual a 1 => 'studio'
#     + Se o valor da coluna "bedrooms" for igual a 2 => 'apartment'
#     + Se o valor da coluna "bedrooms" for maior que 2 => 'house'
