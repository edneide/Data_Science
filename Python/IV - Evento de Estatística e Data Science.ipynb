# %% [markdown]
# # Dados de custos médicos - Seguro

# %% [markdown]
# # 1. Instalando e carregando o PyCaret

# %%
# pip install pycaret

# %% [markdown]
# - Mais informações sobre o `pycaret`: https://pycaret.org/

# %%
import pycaret
import seaborn as sns
import numpy as np

# %%
from pycaret.datasets import get_data

# %% [markdown]
# # 2. Carregando a base de dados

# %%
dados = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# - esta base de dados também pode ser encontrada no Kaggle: https://www.kaggle.com/mirichoi0218/insurance

# %% [markdown]
# - Visualização de algumas informações:

# %%
sns.scatterplot(x = 'bmi', y = 'charges', hue = 'smoker', data = dados)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# - Os custos (`charges`) para não fumantes parecem ser menores.

# %% [markdown]
# # 3. Objetivo: construir um bom modelo para previsão dos custos médicos de uma pessoa

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8c/4qj1vrpn4zv0v54qptvr3fjr0000gn/T/ipykernel_7687/215956045.py in <module>
# ----> 1 from pycaret.regression import *
#
# /usr/local/lib/python3.9/site-packages/pycaret/regression.py in <module>
#       8 import numpy as np
#       9
# ---> 10 import pycaret.internal.tabular
#      11 from pycaret.internal.Display import Display, is_in_colab, enable_colab
#      12 from typing import List, Tuple, Any, Union, Optional, Dict
#
# /usr/local/lib/python3.9/site-packages/pycaret/internal/tabular.py in <module>
#       7 from enum import Enum, auto
#       8 import math
# ----> 9 from pycaret.internal.meta_estimators import (
#      10     PowerTransformedTargetRegressor,
#      11     get_estimator_from_meta_estimator,
#
# /usr/local/lib/python3.9/site-packages/pycaret/internal/meta_estimators.py in <module>
# ...
